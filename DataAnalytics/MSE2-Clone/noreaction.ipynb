# %% [markdown]
# # Data Analytics (IT 202B) section IV sem Section B 2025-26
#
# ### Experiment 6
#
# Name-Khushi Tomar
# University Rollno- 202401100500086
# CSIT-4B

# %%
csv_path="C:\Projects\Project\Programs\DataAnalytics\MSE2-Clone\StudentsPerformance.csv"
print(csv_path)
# Out:
# C:\Projects\Project\Programs\DataAnalytics\MSE2-Clone\StudentsPerformance.csv

# %%
import pandas as pd
df=pd.read_csv(csv_path)
print(df.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#Q1. Using the given dataset, identify the input features and target 
#variable and split the data into training and testing sets. 
from sklearn.preprocessing import LabelEncoder
y=df["test preparation course"]
x=df.drop(["test preparation course"],axis=1)
le=LabelEncoder()
y=le.fit_transform(y)
x=pd.get_dummies(x)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Q2. Apply a Decision Tree classifier on the dataset to predict student 
#performance and display the classification results. 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
y_pred_dt = model_dt.predict(X_test)
print("Decision Tree Results:\n")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Results:
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50        79
#            1       0.68      0.76      0.72       121
#
#     accuracy                           0.64       200
#    macro avg       0.62      0.61      0.61       200
# weighted avg       0.63      0.64      0.63       200

# %%
#Q3. Normalize the numerical features and implement the k-NN 
#algorithm to classify student performance. 

#normalize
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#knn
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(X_train_scaled, y_train)
y_pred_knn = model_knn.predict(X_test_scaled)
print("KNN Results:\n")
print(classification_report(y_test, y_pred_knn))
# Out:
# KNN Results:
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.20      0.28        79
#            1       0.62      0.83      0.71       121
#
#     accuracy                           0.58       200
#    macro avg       0.53      0.52      0.49       200
# weighted avg       0.55      0.58      0.54       200

# %%
#Q4. Implement the Naïve Bayes algorithm on the dataset to predict 
#the performance category of students. 
from sklearn.naive_bayes import GaussianNB

model_nb = GaussianNB()
model_nb.fit(X_train, y_train)
y_pred_nb = model_nb.predict(X_test)
print("Naive Bayes Results:\n")
print(classification_report(y_test, y_pred_nb))
# Out:
# Naive Bayes Results:
#
#               precision    recall  f1-score   support
#
#            0       0.48      0.41      0.44        79
#            1       0.65      0.72      0.68       121
#
#     accuracy                           0.59       200
#    macro avg       0.57      0.56      0.56       200
# weighted avg       0.58      0.59      0.59       200

# %%
#Q5. Evaluate the classification model using Confusion Matrix, 
#Accuracy, Precision, Recall, and F1-Score.(For any algorithm) 
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))

print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Precision:", precision_score(y_test, y_pred_dt))
print("Recall:", recall_score(y_test, y_pred_dt))
print("F1 Score:", f1_score(y_test, y_pred_dt))
# Out:
# Confusion Matrix:
#  [[36 43]
#  [29 92]]
# Accuracy: 0.64
# Precision: 0.6814814814814815
# Recall: 0.7603305785123967
# F1 Score: 0.71875

# %%
#Q6. Apply K-Means clustering on the dataset (excluding the target 
#variable) to group students based on learning patterns.
from sklearn.cluster import KMeans

X_cluster = x.copy()
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_cluster)
df["cluster"] = clusters
print(df[["cluster"]].head())
# Out:
#    cluster
# 0        0
# 1        1
# 2        1
# 3        2
# 4        1
